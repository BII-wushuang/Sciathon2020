# %% [markdown]
# <a href="https://colab.research.google.com/github/BII-wushuang/Sciathon2020/blob/master/MiniQ.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Introduction**
#
# Some introductory remarks, scope, and intended audience should go up top here.

# %% [markdown]
# To use this notebook, simply step through each code cell, running them in sequence to see the outcomes. For cells that include interactive elements, feel free to take your time and play around with the widgets!
#
# When it comes time to make your own circuits to help our kitten friend along their way, try going back to the first widget for some inspiration.

# %% [markdown]
# First things first, make sure that qiskit and the helper library is installed and working on our instance. You can comment the pip install lines once it's here.

# %%
# Some housekeeping where we install qiskit, import the methods, and define our
# local quantum simulator
#!pip install qiskit
#!pip install --upgrade git+https://github.com/kylegodbey/quantumlib.git

import qiskit
import numpy as np

from qiskit.visualization import plot_histogram
from qiskit.tools.jupyter import *
from quantumlib import plot_state_qsphere
from quantumlib.widgets import minicomposer
from qlib_common import statevec

# Use BasicAer's qasm_simulator
backend_sim = qiskit.BasicAer.get_backend('qasm_simulator')

# %% [markdown]
# # Alice in Quantum Land

# %% [markdown]
# Now, let's play around in the quantum world to see what happens when we run through a few scenarios with Ket the quantum cat.
#
# (For story folks, this composer is a nice visual representation of the states after various transformations, so feel free to repeat this block many times or just say in the text to go back here and add another gate)

# %%
minicomposer(1, qsphere=True)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Label(value='Select a gate to add to the circuit:')
# ...
# HTML(value='')

# %% [markdown]
# Now let's build a quantum circuit to help Ket get to where they need to go!
#
# (The code is filled in for now, but like the IBM tutorial, this is where the hand-on building of the circuit can come in)

# %%
def create_circuit():
    qc = qiskit.QuantumCircuit(1)
    qc.h(0)
    return qc

qc = create_circuit()
state = statevec(qc)
plot_state_qsphere(state.data)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
